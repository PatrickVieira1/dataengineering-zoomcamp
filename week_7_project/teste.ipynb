# %%
import pandas as pd
import requests
import os

# %%
# !wget 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsas/ca/ca-2011-01.csv'
# Out:
# --2023-04-02 19:43:03--  https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsas/ca/ca-2011-01.csv
# Resolving www.gov.br (www.gov.br)... 161.148.164.31
# Connecting to www.gov.br (www.gov.br)|161.148.164.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 112871260 (108M) [text/csv]
# Saving to: ‘ca-2011-01.csv’
#
# ca-2011-01.csv      100%[===================>] 107.64M  1.78MB/s    in 60s
#
# 2023-04-02 19:44:04 (1.78 MB/s) - ‘ca-2011-01.csv’ saved [112871260/112871260]

# %%
df = pd.read_csv('ca-2011-01.csv',
                 header=0,
                 sep=';',
                 decimal=',',
                 dtype={
                     'Valor de Venda': float,
                     'Valor de Compra': float
                 },
                 parse_dates=['Data da Coleta'],
                 dayfirst=True,
                 encoding='utf8'
                 )

df.head()
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio  \
# 0             SE             SP  ARARAQUARA
# 1             SE             SP  ARARAQUARA
# 2             SE             SP  ARARAQUARA
# 3             SE             SP   GUARULHOS
# 4             SE             SP   GUARULHOS
#
#                                   Revenda      CNPJ da Revenda  \
# 0  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 1  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 2  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 3                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
#
#                     Nome da Rua Numero Rua          Complemento      Bairro  \
# 0  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 1  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 2  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 3      RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 4      RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
#
#          Cep   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0  14801-970  GASOLINA     2011-01-04           2.540              NaN
# 1  14801-970    ETANOL     2011-01-04           1.730              NaN
# 2  14801-970    DIESEL     2011-01-04           2.050              NaN
# 3  07178-580  GASOLINA     2011-01-05           2.497              NaN
# 4  07178-580    ETANOL     2011-01-05           1.749              NaN
#
#   Unidade de Medida                      Bandeira
# 0        R$ / litro                        BRANCA
# 1        R$ / litro                        BRANCA
# 2        R$ / litro                        BRANCA
# 3        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 4        R$ / litro  PETROBRAS DISTRIBUIDORA S.A.

# %%
columns_to_rename = {
    'Regiao - Sigla': 'regiao_sigla', 
    'Estado - Sigla': 'estado_sigla', 
    'Municipio': 'municipio', 
    'Revenda': 'revenda',
    'CNPJ da Revenda': 'cnpj_revenda',
    'Nome da Rua': 'endereço', 
    'Numero Rua': 'numero_rua', 
    'Complemento': 'complemento', 
    'Bairro': 'bairro',
    'Cep': 'cep', 
    'Produto': 'produto',
    'Data da Coleta': 'data_da_coleta',
    'Valor de Venda': 'valor_venda',
    'Valor de Compra': 'valor_compra',
    'Unidade de Medida': 'unidade_medida',
    'Bandeira': 'bandeira'
}

df = df.rename(columns=columns_to_rename)

# %%
print(pd.io.sql.get_schema(df, 'gas_prices_brazil'))
# Out:
# CREATE TABLE "gas_prices_brazil" (
# "regiao_sigla" TEXT,
#   "estado_sigla" TEXT,
#   "municipio" TEXT,
#   "revenda" TEXT,
#   "cnpj_revenda" TEXT,
#   "endereço" TEXT,
#   "numero_rua" TEXT,
#   "complemento" TEXT,
#   "bairro" TEXT,
#   "cep" TEXT,
#   "produto" TEXT,
#   "data_da_coleta" TIMESTAMP,
#   "valor_venda" REAL,
#   "valor_compra" REAL,
#   "unidade_medida" TEXT,
#   "bandeira" TEXT
# )

# %%
df.head()
# Out:
#   regiao_sigla estado_sigla   municipio  \
# 0           SE           SP  ARARAQUARA
# 1           SE           SP  ARARAQUARA
# 2           SE           SP  ARARAQUARA
# 3           SE           SP   GUARULHOS
# 4           SE           SP   GUARULHOS
#
#                                   revenda         cnpj_revenda  \
# 0  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 1  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 2  RAIZEN ARARAQUARA ACUCAR E ALCOOL LTDA   43.960.335/0001-64
# 3                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
# 4                AUTO POSTO SAKAMOTO LTDA   49.051.667/0001-02
#
#                        endereço numero_rua          complemento      bairro  \
# 0  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 1  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 2  RODOVIA FRANCISCO JOSE ZANIN       Km 4                  NaN  ZONA RURAL
# 3      RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
# 4      RODOVIA PRESIDENTE DUTRA        S/N  KM 210,5-SENT SP/RJ  BONSUCESSO
#
#          cep   produto data_da_coleta  valor_venda  valor_compra  \
# 0  14801-970  GASOLINA     2011-01-04        2.540           NaN
# 1  14801-970    ETANOL     2011-01-04        1.730           NaN
# 2  14801-970    DIESEL     2011-01-04        2.050           NaN
# 3  07178-580  GASOLINA     2011-01-05        2.497           NaN
# 4  07178-580    ETANOL     2011-01-05        1.749           NaN
#
#   unidade_medida                      bandeira
# 0     R$ / litro                        BRANCA
# 1     R$ / litro                        BRANCA
# 2     R$ / litro                        BRANCA
# 3     R$ / litro  PETROBRAS DISTRIBUIDORA S.A.
# 4     R$ / litro  PETROBRAS DISTRIBUIDORA S.A.

# %%
df = pd.read_parquet('parquet_files_ca-2004-01.parquet')

df.columns[0]
# Out:
# 'ï»¿Regiao - Sigla'

# %%
columns_to_rename = {
    df.columns[0]: 'regiao_sigla', 
    df.columns[1]: 'estado_sigla', 
    df.columns[2]: 'municipio', 
    df.columns[3]: 'revenda',
    df.columns[4]: 'cnpj_revenda',
    df.columns[5]: 'endereço', 
    df.columns[6]: 'numero_rua', 
    df.columns[7]: 'complemento', 
    df.columns[8]: 'bairro',
    df.columns[9]: 'cep', 
    df.columns[10]: 'produto',
    df.columns[11]: 'data_da_coleta',
    df.columns[12]: 'valor_venda',
    df.columns[13]: 'valor_compra',
    df.columns[14]: 'unidade_medida',
    df.columns[15]: 'bandeira'
}

# %%
df = df.rename(columns=columns_to_rename)

df.columns
# Out:
# Index(['regiao_sigla', 'estado_sigla', 'municipio', 'revenda', 'cnpj_revenda',
#        'endereço', 'numero_rua', 'complemento', 'bairro', 'cep', 'produto',
#        'data_da_coleta', 'valor_venda', 'valor_compra', 'unidade_medida',
#        'bandeira'],
#       dtype='object')
